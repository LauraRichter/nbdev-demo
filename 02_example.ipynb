# %% [markdown]
# # example
#
# > First example

# %%
#| default_exp example

# %%
#| export
import matplotlib.pylab as plt
import numpy as np

# %%
#| export

def simulate_data():
    x = np.arange(24)
    y = x ** 2
    return x, y

# %%
x, y = simulate_data()
plt.plot(x, y)

# %%
n = 15
plt.plot(np.random.randn(n))

# %%
#| hide
import nbdev; nbdev.nbdev_export()
